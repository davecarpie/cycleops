# %%
import pandas as pd
import geopandas as gpd
from shapely import wkt

# Load NTA polygons
nta = pd.read_csv("NYC_NTAs.csv")

# Convert WKT → geometry
nta["geometry"] = nta["the_geom"].apply(wkt.loads)

gdf_nta = gpd.GeoDataFrame(
    nta,
    geometry="geometry",
    crs="EPSG:4326"
)

# %%
citibike_df = pd.read_csv('202601-citibike-tripdata_2.csv')

# %%
# Extract unique start stations
start_stations = citibike_df[["start_station_id", "start_station_name", "start_lat", "start_lng"]].drop_duplicates()

# Extract unique end stations
end_stations = citibike_df[["end_station_id", "end_station_name", "end_lat", "end_lng"]].drop_duplicates()

# Rename end columns to match start columns
end_stations = end_stations.rename(columns={
    "end_station_id": "station_id",
    "end_station_name": "station_name",
    "end_lat": "lat",
    "end_lng": "lng"
})

start_stations = start_stations.rename(columns={
    "start_station_id": "station_id",
    "start_station_name": "station_name",
    "start_lat": "lat",
    "start_lng": "lng"
})

# Combine and dedupe
stations = pd.concat([start_stations, end_stations], ignore_index=True).drop_duplicates("station_id")

gdf_stations = gpd.GeoDataFrame(
    stations,
    geometry=gpd.points_from_xy(stations.lng, stations.lat),
    crs="EPSG:4326"
)

stations_with_nta = gpd.sjoin(
    gdf_stations,
    gdf_nta[["NTA2020", "NTAName", "BoroName", "geometry"]],
    how="left",
    predicate="within"
)

# %%
stations_with_bergen = stations_with_nta[
    stations["station_name"].str.contains("bergen", case=False, na=False)
]

print(stations_with_bergen)
# Out:
#      station_id                    station_name        lat        lng  \
# 221     4281.08        Bergen St & Flatbush Ave  40.680945 -73.975673
# 264     4190.06           Grand Ave & Bergen St  40.678045 -73.962408
# 291     4072.02         Bergen St & Buffalo Ave  40.674700 -73.925120
# 374     4066.15         Bedford Ave & Bergen St  40.676368 -73.952918
# 475     4446.01            Bergen St & Smith St  40.686744 -73.990632
# 563     4322.06               Bergen St & 4 Ave  40.682564 -73.979898
# 775     4404.10             Bond St & Bergen St  40.684967 -73.986208
# 789     4064.03        Bergen St & Saratoga Ave  40.674230 -73.916560
# 790     4048.03            Bergen St & Troy Ave  40.675240 -73.935960
# 791     4157.10      Bergen St & Vanderbilt Ave  40.679439 -73.968044
# 1273    4089.01        Bergen St & Kingston Ave  40.675600 -73.941500
# 1326    4055.04  Bergen St & Mother Gaston Blvd  40.673740 -73.908520
# 1778    7858.02           Bergen Ave & E 152 St  40.817166 -73.914737
# 1898    7840.11           E 147 St & Bergen Ave  40.814673 -73.918390
#
#                         geometry  index_right NTA2020  \
# 221   POINT (-73.97567 40.68094)         21.0  BK0602
# 264   POINT (-73.96241 40.67804)         26.0  BK0801
# 291    POINT (-73.92512 40.6747)         27.0  BK0802
# 374   POINT (-73.95292 40.67637)         27.0  BK0802
# 475   POINT (-73.99063 40.68674)          5.0  BK0202
# 563    POINT (-73.9799 40.68256)         20.0  BK0601
# 775   POINT (-73.98621 40.68497)         20.0  BK0601
# 789   POINT (-73.91656 40.67423)         52.0  BK1601
# 790   POINT (-73.93596 40.67524)         27.0  BK0802
# 791   POINT (-73.96804 40.67944)         26.0  BK0801
# 1273    POINT (-73.9415 40.6756)         27.0  BK0802
# 1326  POINT (-73.90852 40.67374)         52.0  BK1601
# 1778  POINT (-73.91474 40.81717)         70.0  BX0102
# 1898  POINT (-73.91839 40.81467)         69.0  BX0101
#
#                                            NTAName  BoroName
# 221                                     Park Slope  Brooklyn
# 264                               Prospect Heights  Brooklyn
# 291                          Crown Heights (North)  Brooklyn
# 374                          Crown Heights (North)  Brooklyn
# 475            Downtown Brooklyn-DUMBO-Boerum Hill  Brooklyn
# 563   Carroll Gardens-Cobble Hill-Gowanus-Red Hook  Brooklyn
# 775   Carroll Gardens-Cobble Hill-Gowanus-Red Hook  Brooklyn
# 789                                     Ocean Hill  Brooklyn
# 790                          Crown Heights (North)  Brooklyn
# 791                               Prospect Heights  Brooklyn
# 1273                         Crown Heights (North)  Brooklyn
# 1326                                    Ocean Hill  Brooklyn
# 1778                                       Melrose     Bronx
# 1898                        Mott Haven-Port Morris     Bronx

# %%
# Merge start NTA
citibike_df = citibike_df.merge(
    stations_with_nta[["station_id", "NTAName", "BoroName"]].rename(columns={"station_id": "start_station_id", "NTAName": "start_NTA", "BoroName": "start_Boro"}),
    on="start_station_id",
    how="left"
)

# Merge end NTA
citibike_df = citibike_df.merge(
    stations_with_nta[["station_id", "NTAName", "BoroName"]].rename(columns={"station_id": "end_station_id", "NTAName": "end_NTA", "BoroName": "end_Boro"}),
    on="end_station_id",
    how="left"
)

citibike_df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  0179695DC1F74E4E   classic_bike  2026-01-09 15:39:44.131
# 1  5D0645202DDFA256  electric_bike  2026-01-09 10:14:39.226
# 2  4572C883BF0165E4   classic_bike  2026-01-14 18:44:00.839
# 3  3575D616D0179F57  electric_bike  2026-01-06 05:57:18.257
# 4  895D2DC8F8BA4177  electric_bike  2026-01-02 16:19:07.373
#
#                   ended_at                   start_station_name  \
# 0  2026-01-09 15:44:27.970  Adam Clayton Powell Blvd & W 115 St
# 1  2026-01-09 10:18:56.254                Carlton Ave & Dean St
# 2  2026-01-14 18:52:54.180                 Broadway & Morris St
# 3  2026-01-06 06:15:40.651            Van Brunt St & Wolcott St
# 4  2026-01-02 16:24:19.447                     W 33 St & 10 Ave
#
#   start_station_id                 end_station_name end_station_id  start_lat  \
# 0          7643.18  St Nicholas Ave & Manhattan Ave        7723.01  40.802535
# 1          4199.12          3 Ave & Schermerhorn St        4437.01  40.680974
# 2          5033.01          Lispenard St & Broadway        5391.06  40.705945
# 3          4095.03             Vesey St & Church St        5216.06  40.677343
# 4          6492.04                  6 Ave & W 33 St        6364.07  40.753773
#
#    start_lng    end_lat    end_lng member_casual  \
# 0 -73.953242  40.809725 -73.953149        member
# 1 -73.971010  40.686832 -73.979677        member
# 2 -74.013219  40.719392 -74.002472        member
# 3 -74.012751  40.712220 -74.010472        member
# 4 -73.999376  40.749013 -73.988484        member
#
#                                       start_NTA start_Boro  \
# 0                                Harlem (South)  Manhattan
# 1                              Prospect Heights   Brooklyn
# 2          Financial District-Battery Park City  Manhattan
# 3  Carroll Gardens-Cobble Hill-Gowanus-Red Hook   Brooklyn
# 4                          Chelsea-Hudson Yards  Manhattan
#
#                                 end_NTA   end_Boro
# 0                        Harlem (South)  Manhattan
# 1   Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn
# 2                  Tribeca-Civic Center  Manhattan
# 3  Financial District-Battery Park City  Manhattan
# 4   Midtown South-Flatiron-Union Square  Manhattan

# %%
top_start_ntas = (
    citibike_df
    .groupby("start_NTA")
    .size()
    .reset_index(name="n_rides_start")
    .sort_values("n_rides_start", ascending=False)
)
print(top_start_ntas.head(15))

top_end_ntas = (
    citibike_df
    .groupby("end_NTA")
    .size()
    .reset_index(name="n_rides_end")
    .sort_values("n_rides_end", ascending=False)
)
print(top_end_ntas.head(15))
# Out:
#                                         start_NTA  n_rides_start
# 19                           Chelsea-Hudson Yards          57335
# 38                                   East Village          43867
# 74                           Midtown-Times Square          40308
# 73            Midtown South-Flatiron-Union Square          36008
# 118                                  Williamsburg          32358
# 81                           Murray Hill-Kips Bay          30694
# 55                                 Hell's Kitchen          25707
# 51                              Greenwich Village          23631
# 117                                  West Village          21670
# 69                                Lower East Side          21035
# 93                SoHo-Little Italy-Hudson Square          18987
# 111                Upper West Side-Lincoln Square          17949
# 17   Carroll Gardens-Cobble Hill-Gowanus-Red Hook          17641
# 50                                     Greenpoint          17570
# 37                        East Midtown-Turtle Bay          17044
#                                           end_NTA  n_rides_end
# 19                           Chelsea-Hudson Yards        56201
# 38                                   East Village        42865
# 74                           Midtown-Times Square        41540
# 73            Midtown South-Flatiron-Union Square        36564
# 118                                  Williamsburg        32161
# 81                           Murray Hill-Kips Bay        31268
# 51                              Greenwich Village        25443
# 55                                 Hell's Kitchen        24223
# 69                                Lower East Side        21359
# 117                                  West Village        20420
# 93                SoHo-Little Italy-Hudson Square        19417
# 41           Financial District-Battery Park City        18638
# 111                Upper West Side-Lincoln Square        18218
# 17   Carroll Gardens-Cobble Hill-Gowanus-Red Hook        17444
# 50                                     Greenpoint        17396

# %%
nta_flows = (
    citibike_df
    .groupby(["start_NTA", "start_Boro", "end_NTA", "end_Boro"])
    .size()
    .reset_index(name="n_rides")
    .sort_values("n_rides", ascending=False)
)
nta_flows_not_same = nta_flows[(nta_flows["start_Boro"] != nta_flows["end_Boro"]) & ((nta_flows["start_Boro"] == "Manhattan") | (nta_flows["end_Boro"] == "Manhattan"))]
nta_flows_not_same.head(30)
# Out:
#                                         start_NTA start_Boro  \
# 5581                                 Williamsburg   Brooklyn
# 3186                              Lower East Side  Manhattan
# 5596                                 Williamsburg   Brooklyn
# 4424              SoHo-Little Italy-Hudson Square  Manhattan
# 5563                                 Williamsburg   Brooklyn
# 1814                                 East Village  Manhattan
# 5566                                 Williamsburg   Brooklyn
# 5554                                 Williamsburg   Brooklyn
# 4808                         Tribeca-Civic Center  Manhattan
# 983                         Chinatown-Two Bridges  Manhattan
# 941                         Chinatown-Two Bridges  Manhattan
# 1349          Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn
# 1396          Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn
# 2359                                   Greenpoint   Brooklyn
# 5603                                 Williamsburg   Brooklyn
# 1361          Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn
# 4252          Queensbridge-Ravenswood-Dutch Kills     Queens
# 2005         Financial District-Battery Park City  Manhattan
# 5061  Upper East Side-Lenox Hill-Roosevelt Island  Manhattan
# 3150                              Lower East Side  Manhattan
# 1571                          East Harlem (North)  Manhattan
# 1358          Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn
# 1762                                 East Village  Manhattan
# 1952         Financial District-Battery Park City  Manhattan
# 3066               Long Island City-Hunters Point     Queens
# 5573                                 Williamsburg   Brooklyn
# 5044  Upper East Side-Lenox Hill-Roosevelt Island  Manhattan
# 1855                            East Williamsburg   Brooklyn
# 3142                              Lower East Side  Manhattan
# 2462                            Greenwich Village  Manhattan
#
#                                           end_NTA   end_Boro  n_rides
# 5581                              Lower East Side  Manhattan     1085
# 3186                                 Williamsburg   Brooklyn      960
# 5596              SoHo-Little Italy-Hudson Square  Manhattan      637
# 4424                                 Williamsburg   Brooklyn      548
# 5563                                 East Village  Manhattan      537
# 1814                                 Williamsburg   Brooklyn      437
# 5566         Financial District-Battery Park City  Manhattan      340
# 5554                        Chinatown-Two Bridges  Manhattan      335
# 4808          Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn      325
# 983                                  Williamsburg   Brooklyn      317
# 941           Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn      315
# 1349                        Chinatown-Two Bridges  Manhattan      306
# 1396                         Tribeca-Civic Center  Manhattan      298
# 2359                              Lower East Side  Manhattan      282
# 5603                         Tribeca-Civic Center  Manhattan      276
# 1361         Financial District-Battery Park City  Manhattan      266
# 4252  Upper East Side-Lenox Hill-Roosevelt Island  Manhattan      249
# 2005                                 Williamsburg   Brooklyn      246
# 5061          Queensbridge-Ravenswood-Dutch Kills     Queens      239
# 3150                                   Greenpoint   Brooklyn      233
# 1571                       Mott Haven-Port Morris      Bronx      230
# 1358                                 East Village  Manhattan      227
# 1762          Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn      225
# 1952          Downtown Brooklyn-DUMBO-Boerum Hill   Brooklyn      216
# 3066  Upper East Side-Lenox Hill-Roosevelt Island  Manhattan      215
# 5573                            Greenwich Village  Manhattan      213
# 5044               Long Island City-Hunters Point     Queens      213
# 1855                              Lower East Side  Manhattan      209
# 3142                            East Williamsburg   Brooklyn      207
# 2462                                 Williamsburg   Brooklyn      202
